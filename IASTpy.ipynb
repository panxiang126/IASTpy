# %%
print("dsa")
# Out:
# dsa

# %%
arr=input("dasfa:")
# Out:
# dasfa: sada

# %%
arr
# Out:
# 'sada'

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_61/2172125874.py in <module>
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'
